# %%
# !apt-get update && apt-get install libgl1 -y

# %%
# pip install dask pandas numpy matplotlib seaborn torch scikit-learn opencv-python

# %%
# !unzip archive.zip

# %% [markdown]
# # Introduction
#
# **Objectives**: train and apply knowledge about Convolutional Neural Network to create and train a model to predict the weather from an image.
#
# **Technologies Used**:
#
# **Pytorch** for load the data, build the model architeture, train it and avaliate it with new images.
#
# **OpenCV** for image reading and processing.
#
# **Pandas and NumPy** for data manipulation and organization.
#
# **Scikit-Learn** for metric, classification report and train_test_split.
#
# **Matplotlib and Seaborn** for Data and Images Visualization

# %% [markdown]
# # Imports

# %%
# - Data Manipulation - #
import numpy as np
import pandas as pd
import dask.array as da
import dask
from dask.diagnostics import ProgressBar

# - Data Visualization and Image Transformation - #
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import cv2

# - Datasets manipulation and Neural Network - #
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset

# - Data Preparation and Model Validation - #
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score


# - Utils - #
import time
import gc
import requests
import os

# %%
# - Get the Font - #
url = "https://github.com/lucas142129silva/Movies-Exploratory-Data-Analysis/blob/main/fonts/FRAMD_M.ttf?raw=true"
r = requests.get(url)
with open("./framd_m.ttf", "wb") as f:
    f.write(r.content)

font = fm.FontProperties(fname="./framd_m.ttf")

# %%
cd /home
# Out:
# /home

# %% [markdown]
# # Reading the data

# %%
data = list()

for dirname, _, filenames in os.walk('./dataset'):
    for filename in filenames:
        label = dirname.split("/")[-1]
        image = os.path.join(dirname, filename)
        data.append((label, image))

# %%
df = pd.DataFrame(data, columns=["label", "image"])
df.head()
# Out:
#   label                   image
# 0   dew  ./dataset/dew/2208.jpg
# 1   dew  ./dataset/dew/2209.jpg
# 2   dew  ./dataset/dew/2210.jpg
# 3   dew  ./dataset/dew/2211.jpg
# 4   dew  ./dataset/dew/2212.jpg

# %%
df.describe()
# Out:
#        label                   image
# count   6862                    6862
# unique    11                    6862
# top     rime  ./dataset/dew/2208.jpg
# freq    1160                       1

# %%
unique_labels = df['label'].unique()
unique_labels
# Out:
# array(['dew', 'fogsmog', 'frost', 'glaze', 'hail', 'lightning', 'rain',
#        'rainbow', 'rime', 'sandstorm', 'snow'], dtype=object)

# %%
examples = pd.DataFrame([])
for label in unique_labels:
    examples = pd.concat([examples, df.query(f"label == '{label}'").sample(1)])

# %% [markdown]
# # Transforming the data
#
# **Transform paths into arrays**: Pytorch can handle float32 NumPy arrays, so it reads using the OpenCV library and transform the image into a NumPy array resized to 256 x 256.

# %%
def process_image(img):
    try:
        pic = cv2.imread(img)
        pic = cv2.cvtColor(pic, cv2.COLOR_BGR2RGB)
        pic = cv2.resize(pic, (256, 256), interpolation=cv2.INTER_AREA)
        pic = np.array(pic, dtype=np.float32)
        return pic
    except:
        return np.zeros(shape=(256, 256, 3), dtype=np.float32)

# %%
list_of_paths = df["image"].to_numpy()

# %% [markdown]
# ## Using numpy array

# %%
# %%time

images = [process_image(path) for path in list_of_paths]
images = np.array(images, dtype=np.float32)
print(images.shape)
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# (6862, 256, 256, 3)
# CPU times: user 1min 14s, sys: 3min 29s, total: 4min 44s
# Wall time: 33 s

# %% [markdown]
# ## Using Dask delayed

# %%
# %%time
process_image_delayed = dask.delayed(process_image)
images = [process_image_delayed(path) for path in list_of_paths]

# Compute the results in parallel
with ProgressBar():
    images = dask.compute(*images)

# Convert the list to a Dask array
images = da.from_array(np.array(images, dtype=np.float32))
images = images.compute()
print(images.shape)
# Out:
# [###################                     ] | 49% Completed | 1.77 s ms
# libpng warning: iCCP: known incorrect sRGB profile
# [#######################                 ] | 58% Completed | 2.07 s
# libpng warning: iCCP: known incorrect sRGB profile
# [################################        ] | 80% Completed | 2.88 s
# libpng warning: iCCP: known incorrect sRGB profile
# [########################################] | 100% Completed | 3.69 s
# (6862, 256, 256, 3)
# CPU times: user 44.4 s, sys: 29.9 s, total: 1min 14s
# Wall time: 10.7 s

# %% [markdown]
# # Vectorizing the labels
#
# Machine Learning models use numeric values, so it transform each array into its unique value, numbers in the lengh of the total of labels.

# %%
unique_labels = list(unique_labels) # Use for indexing the labels - ("hail", 0), ("rainbow", 1)

labels = df["label"].to_numpy()

# Using the unique labels list
def convert_categorical_to_number(label):
    return unique_labels.index(label)

func = np.vectorize(convert_categorical_to_number)
labels = func(labels)
labels
# Out:
# array([ 0,  0,  0, ..., 10, 10, 10])

# %% [markdown]
# # Preparing the data
#
# ### Split into train and test

# %%
images_train, images_test, labels_train, labels_test = train_test_split(images, labels, test_size=0.2)

# %%
print("Sizes:\n")
print("# - Train", images_train.shape, sep="\n")
print(labels_train.shape)
print("# - Test", images_test.shape, sep="\n")
print(labels_test.shape)
# Out:
# Sizes:
#
# # - Train
# (5489, 256, 256, 3)
# (5489,)
# # - Test
# (1373, 256, 256, 3)
# (1373,)

# %% [markdown]
# ### Tranforming the data into Torch Tensor
#
# The torch tensor has its size like (Batch x Color Channels x Height x Width), so it needs to permute the dimensions to get it right for images that have its size from readind like (Batch x Height x Width x Color Channels)

# %%
images_train = torch.from_numpy(images_train).permute(0, 3, 1, 2)
images_test = torch.from_numpy(images_test).permute(0, 3, 1, 2)
labels_train = torch.from_numpy(labels_train)
labels_test = torch.from_numpy(labels_test)

# %%
# Free Memory
del images
_ = gc.collect()

# %% [markdown]
# # Defining the hyperparameters

# %%
# Hyperparams Configuration.
args = {
    'epoch_num': 20,
    'lr': 1e-3,           # Learning Rate
    'weight_decay': 1e-3, # L2 Penalty
    'batch_size': 256
}

# %% [markdown]
# # Checking the number of GPU available

# %%
if torch.cuda.is_available():
    args["device"] = torch.device("cuda:0")
else:
    args["device"] = torch.device("cpu")

print(args["device"])
# Out:
# cuda:0

# %%
gpu_count = torch.cuda.device_count()
print("Number of available GPUs:", gpu_count)
# Out:
# Number of available GPUs: 4

# %% [markdown]
# # Building the dataloader

# %%
class ImagesLabelsDataset(Dataset):
    def __init__(self, images_array, labels_array, scaler_feat=None, scaler_label=None):

        self.labels = labels_array
        self.images = images_array

    def __getitem__(self, idx):

        sample = self.images[idx]
        label  = self.labels[idx]

        return sample, label

    def __len__(self):
        return len(self.labels)

# %%
# - Dataset first - #
train_set = ImagesLabelsDataset(images_train, labels_train)
test_set = ImagesLabelsDataset(images_test, labels_test)

# - Dataloader - #
train_loader = DataLoader(train_set,
                          args['batch_size'],
                          shuffle=True)
test_loader = DataLoader(test_set,
                         args['batch_size'],
                         shuffle=False)

# %%
for batch in train_loader:
    img, lbl = batch
    print('## Batch shape ##')
    print(img.size(), lbl.size())
    break
# Out:
# ## Batch shape ##
# torch.Size([256, 3, 256, 256]) torch.Size([256])

# %% [markdown]
# # Model Architecture

# %%
class ConvolutionalModel(nn.Module):
    def __init__(self, output_size):
        super().__init__()
        self.net = nn.Sequential(
            ## ConvBlock 1
            nn.Conv2d(3, 6, kernel_size=4, stride=1, padding=0),
            # Input: (b, 3, 256, 256) || Output: (b, 6, 250, 250)
            nn.BatchNorm2d(6),
            nn.Tanh(),
            nn.AvgPool2d(kernel_size=5, stride=5, padding=0),
            # Input: (b, 6, 250, 250) || Output: (b, 6, 50, 50)

            ## ConvBlock 2
            nn.Conv2d(6, 16, kernel_size=5, stride=1, padding=0),
            # Input: (b, 6, 50, 50) || Output: (b, 16, 46, 46)
            nn.BatchNorm2d(16),
            nn.Tanh(),
            nn.AvgPool2d(kernel_size=2, stride=2, padding=0),
            # Input: (b, 16, 46, 46) || Output: (b, 16, 23, 23)

            ## ConvBlock 3
            nn.Conv2d(16, 32, kernel_size=8, stride=1, padding=0),
            # Input: (b, 16, 23, 23) || Output: (b, 32, 16, 16)
            nn.BatchNorm2d(32),
            nn.Tanh(),
            nn.AvgPool2d(kernel_size=4, stride=4, padding=0),
            # Input: (b, 32, 16, 16) || Output: (b, 32, 4, 4)

            ## ConvBlock 4
            nn.Conv2d(32, 120, kernel_size=4, stride=1, padding=0),
            # Input: (b, 32, 4, 4) || Output: (b, 120, 1, 1)
            nn.BatchNorm2d(120),
            nn.Tanh(),
            nn.Flatten(),  # flat to a vector
            # Input: (b, 120, 1, 1) || Output: (b, 120*1*1) = (b, 120)

            nn.Dropout(p=0.32), # Avoid Overfitting
            ## DenseBlock
            nn.Linear(120, 84),
            # Input: (b, 120) || Output: (b, 84)
            nn.Tanh(),
            nn.Linear(84, output_size)
            # Input: (b, 84) || Output: (b, 10)
        )

    def forward(self, X):
        output = self.net(X)
        return output

# %%
net = ConvolutionalModel(len(unique_labels)).to(args["device"])

# %%
# # os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"
# available_gpus = [torch.cuda.device(i) for i in range(torch.cuda.device_count())]
# available_gpus

# %% [markdown]
# # ~Implementing DataParallel approach~

# %% [markdown]
# if torch.cuda.device_count() > 1:
#     net = nn.DataParallel(net)

# %% [markdown]
# # Training on single GPU

# %% [markdown]
# ### Training Parameters
#
# The loss function chosen was Cross Entropy Loss while the optimizer was Adam, with the hyperparams defined by the arguments dictionary

# %%
criterion = nn.CrossEntropyLoss().to(args['device'])
optimizer = torch.optim.Adam(net.parameters(), lr=args['lr'], weight_decay=args['weight_decay'])

# %% [markdown]
# ### Train and Eval functions

# %%
def train(train_loader, net, epoch):
    net.train()
    start = time.time()

    epoch_loss = list()
    pred_list, label_list = np.array([]), np.array([])

    for batch in train_loader:
        image, label = batch

        # GPU Casting
        image = image.to(args["device"])
        label = label.to(args["device"])

        # Forward
        pred_label = net(image)
        loss = criterion(pred_label, label)
        epoch_loss.append(loss.cpu().data)

        _, pred = torch.max(pred_label, axis=1)
        pred_list = np.append(pred_list, pred.cpu().numpy())
        label_list = np.append(label_list, label.cpu().numpy())

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    epoch_loss = np.asarray(epoch_loss)
    epoch_acc = accuracy_score(label_list, pred_list)
    end = time.time()

    print("## -- Training -- ##")
    print("Epoch: %d || Loss: %.3f +/- %.3f || Accuracy:  %.2f || Time: %.2f" % (epoch, epoch_loss.mean(),
                                                                                epoch_loss.std(), epoch_acc, end-start))

    return epoch_loss.mean()

def validate(test_loader, net, epoch):
    net.eval()
    start = time.time()

    epoch_loss = list()
    pred_list, label_list = np.array([]), np.array([])

    with torch.no_grad():
        for batch in test_loader:
            image, label = batch

            # Casting to GPU
            image = image.to(args["device"])
            label = label.to(args["device"])

            # Forward
            pred_label = net(image)
            loss = criterion(pred_label, label)
            epoch_loss.append(loss.cpu().data)

            _, pred = torch.max(pred_label, axis=1)
            pred_list = np.append(pred_list, pred.cpu().numpy())
            label_list = np.append(label_list, label.cpu().numpy())

    # Transforming to NumPy Array
    epoch_loss = np.asarray(epoch_loss)
    epoch_acc = accuracy_score(label_list, pred_list)
    end = time.time()

    print("*** Validate ***")
    print("Epoch: %d || Loss: %.3f +/- %.3f || Accuracy:  %.2f || Time: %.2f\n" % (epoch, epoch_loss.mean(),
                                                                                epoch_loss.std(), epoch_acc, end-start))

    return epoch_loss.mean()

# %% [markdown]
# ### Training process

# %%
# %%time

train_losses, test_losses = list(), list()

for epoch in range(args["epoch_num"]):
    train_losses.append(train(train_loader, net, epoch))

    test_losses.append(validate(test_loader, net, epoch))
# Out:
# ## -- Training -- ##
# Epoch: 0 || Loss: 1.850 +/- 0.191 || Accuracy:  0.40 || Time: 3.86
# *** Validate ***
# Epoch: 0 || Loss: 1.770 +/- 0.054 || Accuracy:  0.45 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 1 || Loss: 1.601 +/- 0.080 || Accuracy:  0.49 || Time: 3.25
# *** Validate ***
# Epoch: 1 || Loss: 1.822 +/- 0.067 || Accuracy:  0.40 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 2 || Loss: 1.516 +/- 0.069 || Accuracy:  0.52 || Time: 3.21
# *** Validate ***
# Epoch: 2 || Loss: 1.934 +/- 0.072 || Accuracy:  0.35 || Time: 0.70
#
# ## -- Training -- ##
# Epoch: 3 || Loss: 1.450 +/- 0.057 || Accuracy:  0.55 || Time: 3.19
# *** Validate ***
# Epoch: 3 || Loss: 1.733 +/- 0.050 || Accuracy:  0.46 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 4 || Loss: 1.389 +/- 0.075 || Accuracy:  0.56 || Time: 3.19
# *** Validate ***
# Epoch: 4 || Loss: 1.517 +/- 0.063 || Accuracy:  0.52 || Time: 0.70
#
# ## -- Training -- ##
# Epoch: 5 || Loss: 1.301 +/- 0.071 || Accuracy:  0.59 || Time: 3.19
# *** Validate ***
# Epoch: 5 || Loss: 1.442 +/- 0.075 || Accuracy:  0.52 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 6 || Loss: 1.219 +/- 0.088 || Accuracy:  0.61 || Time: 3.27
# *** Validate ***
# Epoch: 6 || Loss: 1.696 +/- 0.066 || Accuracy:  0.45 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 7 || Loss: 1.162 +/- 0.088 || Accuracy:  0.62 || Time: 3.21
# *** Validate ***
# Epoch: 7 || Loss: 1.396 +/- 0.071 || Accuracy:  0.57 || Time: 0.73
#
# ## -- Training -- ##
# Epoch: 8 || Loss: 1.100 +/- 0.066 || Accuracy:  0.64 || Time: 3.25
# *** Validate ***
# Epoch: 8 || Loss: 1.253 +/- 0.078 || Accuracy:  0.58 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 9 || Loss: 1.026 +/- 0.059 || Accuracy:  0.66 || Time: 3.21
# *** Validate ***
# Epoch: 9 || Loss: 1.364 +/- 0.072 || Accuracy:  0.55 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 10 || Loss: 1.000 +/- 0.065 || Accuracy:  0.66 || Time: 3.27
# *** Validate ***
# Epoch: 10 || Loss: 1.232 +/- 0.055 || Accuracy:  0.56 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 11 || Loss: 0.943 +/- 0.077 || Accuracy:  0.68 || Time: 3.21
# *** Validate ***
# Epoch: 11 || Loss: 1.469 +/- 0.082 || Accuracy:  0.53 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 12 || Loss: 0.956 +/- 0.088 || Accuracy:  0.68 || Time: 3.27
# *** Validate ***
# Epoch: 12 || Loss: 1.293 +/- 0.079 || Accuracy:  0.56 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 13 || Loss: 0.953 +/- 0.079 || Accuracy:  0.68 || Time: 3.21
# *** Validate ***
# Epoch: 13 || Loss: 1.208 +/- 0.047 || Accuracy:  0.58 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 14 || Loss: 0.937 +/- 0.083 || Accuracy:  0.68 || Time: 3.21
# *** Validate ***
# Epoch: 14 || Loss: 1.284 +/- 0.045 || Accuracy:  0.58 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 15 || Loss: 0.918 +/- 0.069 || Accuracy:  0.69 || Time: 3.25
# *** Validate ***
# Epoch: 15 || Loss: 1.516 +/- 0.044 || Accuracy:  0.49 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 16 || Loss: 0.894 +/- 0.075 || Accuracy:  0.70 || Time: 3.21
# *** Validate ***
# Epoch: 16 || Loss: 1.124 +/- 0.043 || Accuracy:  0.62 || Time: 0.71
#
# ## -- Training -- ##
# Epoch: 17 || Loss: 0.843 +/- 0.059 || Accuracy:  0.72 || Time: 3.21
# *** Validate ***
# Epoch: 17 || Loss: 1.145 +/- 0.055 || Accuracy:  0.60 || Time: 0.72
#
# ## -- Training -- ##
# Epoch: 18 || Loss: 0.867 +/- 0.069 || Accuracy:  0.71 || Time: 3.27
# *** Validate ***
# Epoch: 18 || Loss: 1.378 +/- 0.054 || Accuracy:  0.55 || Time: 0.73
#
# ## -- Training -- ##
# Epoch: 19 || Loss: 0.826 +/- 0.069 || Accuracy:  0.73 || Time: 3.20
# *** Validate ***
# Epoch: 19 || Loss: 1.081 +/- 0.066 || Accuracy:  0.63 || Time: 0.71
#
# CPU times: user 23min 11s, sys: 1min 40s, total: 24min 52s
# Wall time: 1min 19s

# %% [markdown]
# # Training Results

# %%
# Real Test Values 
validation_images = test_set.images.to(args["device"]) 
validation_labels = test_set.labels

# Predict
y_pred = np.array([np.argmax(net(image.unsqueeze(0)).cpu().detach().numpy()) for image in validation_images])

# Transform the numeric label back to string
validation_labels = list(map(lambda x: unique_labels[x], validation_labels))
y_pred = list(map(lambda x: unique_labels[x], y_pred))

# %%
# Transform the report into a DataFrame
report = classification_report(validation_labels, y_pred, output_dict=True)
report_df = pd.DataFrame(report).T
report_df.index = [i.title() for i in report_df.index]
report_df.columns = [j.title() for j in report_df.columns]

# %% [markdown]
# ### Classification Report

# %%
col_map = sns.color_palette("coolwarm_r", as_cmap=True)
report_df.style.background_gradient(subset="Precision", cmap=col_map)\
               .background_gradient(subset="Recall", cmap=col_map)\
               .background_gradient(subset="F1-Score", cmap=col_map)\
               .set_properties(**{"font-size": "11pt"})
# Out:
# <style type="text/css">
# #T_7dfed_row0_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row0_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row0_col2, #T_7dfed_row1_col0, #T_7dfed_row9_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row0_col3, #T_7dfed_row1_col3, #T_7dfed_row2_col3, #T_7dfed_row3_col3, #T_7dfed_row4_col3, #T_7dfed_row5_col3, #T_7dfed_row6_col3, #T_7dfed_row7_col3, #T_7dfed_row8_col3, #T_7dfed_row9_col3, #T_7dfed_row10_col3, #T_7dfed_row11_col3, #T_7dfed_row12_col3, #T_7dfed_row13_col3 {
#   font-size: 11pt;
# }
# #T_7dfed_row1_col1, #T_7dfed_row10_col1 {
#   background-color: #9ebeff;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row1_col2, #T_7dfed_row5_col2, #T_7dfed_row8_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row2_col0 {
#   background-color: #9fbfff;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row2_col1, #T_7dfed_row2_col2, #T_7dfed_row7_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row3_col0 {
#   background-color: #d55042;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row3_col1 {
#   background-color: #f29274;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row3_col2 {
#   background-color: #e9785d;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row4_col0 {
#   background-color: #f7b89c;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row4_col1 {
#   background-color: #d9dce1;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row4_col2 {
#   background-color: #dcdddd;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row5_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row5_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row6_col0 {
#   background-color: #f7b093;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row6_col1, #T_7dfed_row9_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row6_col2 {
#   background-color: #dbdcde;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row7_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row7_col2 {
#   background-color: #f0cdbb;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row8_col1 {
#   background-color: #e2dad5;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row8_col2 {
#   background-color: #96b7ff;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row9_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row10_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
#   font-size: 11pt;
# }
# #T_7dfed_row10_col2, #T_7dfed_row11_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row11_col1, #T_7dfed_row13_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row11_col2 {
#   background-color: #abc8fd;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row12_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row12_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row12_col2 {
#   background-color: #bed2f6;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row13_col0 {
#   background-color: #bbd1f8;
#   color: #000000;
#   font-size: 11pt;
# }
# #T_7dfed_row13_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
#   font-size: 11pt;
# }
# </style>
# <table id="T_7dfed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7dfed_level0_col0" class="col_heading level0 col0" >Precision</th>
#       <th id="T_7dfed_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_7dfed_level0_col2" class="col_heading level0 col2" >F1-Score</th>
#       <th id="T_7dfed_level0_col3" class="col_heading level0 col3" >Support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7dfed_level0_row0" class="row_heading level0 row0" >Dew</th>
#       <td id="T_7dfed_row0_col0" class="data row0 col0" >0.820690</td>
#       <td id="T_7dfed_row0_col1" class="data row0 col1" >0.762821</td>
#       <td id="T_7dfed_row0_col2" class="data row0 col2" >0.790698</td>
#       <td id="T_7dfed_row0_col3" class="data row0 col3" >156.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7dfed_level0_row1" class="row_heading level0 row1" >Fogsmog</th>
#       <td id="T_7dfed_row1_col0" class="data row1 col0" >0.843537</td>
#       <td id="T_7dfed_row1_col1" class="data row1 col1" >0.708571</td>
#       <td id="T_7dfed_row1_col2" class="data row1 col2" >0.770186</td>
#       <td id="T_7dfed_row1_col3" class="data row1 col3" >175.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7dfed_level0_row2" class="row_heading level0 row2" >Frost</th>
#       <td id="T_7dfed_row2_col0" class="data row2 col0" >0.700000</td>
#       <td id="T_7dfed_row2_col1" class="data row2 col1" >0.194444</td>
#       <td id="T_7dfed_row2_col2" class="data row2 col2" >0.304348</td>
#       <td id="T_7dfed_row2_col3" class="data row2 col3" >108.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7dfed_level0_row3" class="row_heading level0 row3" >Glaze</th>
#       <td id="T_7dfed_row3_col0" class="data row3 col0" >0.415842</td>
#       <td id="T_7dfed_row3_col1" class="data row3 col1" >0.365217</td>
#       <td id="T_7dfed_row3_col2" class="data row3 col2" >0.388889</td>
#       <td id="T_7dfed_row3_col3" class="data row3 col3" >115.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7dfed_level0_row4" class="row_heading level0 row4" >Hail</th>
#       <td id="T_7dfed_row4_col0" class="data row4 col0" >0.527778</td>
#       <td id="T_7dfed_row4_col1" class="data row4 col1" >0.571429</td>
#       <td id="T_7dfed_row4_col2" class="data row4 col2" >0.548736</td>
#       <td id="T_7dfed_row4_col3" class="data row4 col3" >133.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7dfed_level0_row5" class="row_heading level0 row5" >Lightning</th>
#       <td id="T_7dfed_row5_col0" class="data row5 col0" >0.756410</td>
#       <td id="T_7dfed_row5_col1" class="data row5 col1" >0.786667</td>
#       <td id="T_7dfed_row5_col2" class="data row5 col2" >0.771242</td>
#       <td id="T_7dfed_row5_col3" class="data row5 col3" >75.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7dfed_level0_row6" class="row_heading level0 row6" >Rain</th>
#       <td id="T_7dfed_row6_col0" class="data row6 col0" >0.516949</td>
#       <td id="T_7dfed_row6_col1" class="data row6 col1" >0.586538</td>
#       <td id="T_7dfed_row6_col2" class="data row6 col2" >0.549550</td>
#       <td id="T_7dfed_row6_col3" class="data row6 col3" >104.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7dfed_level0_row7" class="row_heading level0 row7" >Rainbow</th>
#       <td id="T_7dfed_row7_col0" class="data row7 col0" >0.370370</td>
#       <td id="T_7dfed_row7_col1" class="data row7 col1" >0.789474</td>
#       <td id="T_7dfed_row7_col2" class="data row7 col2" >0.504202</td>
#       <td id="T_7dfed_row7_col3" class="data row7 col3" >38.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7dfed_level0_row8" class="row_heading level0 row8" >Rime</th>
#       <td id="T_7dfed_row8_col0" class="data row8 col0" >0.824818</td>
#       <td id="T_7dfed_row8_col1" class="data row8 col1" >0.545894</td>
#       <td id="T_7dfed_row8_col2" class="data row8 col2" >0.656977</td>
#       <td id="T_7dfed_row8_col3" class="data row8 col3" >207.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7dfed_level0_row9" class="row_heading level0 row9" >Sandstorm</th>
#       <td id="T_7dfed_row9_col0" class="data row9 col0" >0.623037</td>
#       <td id="T_7dfed_row9_col1" class="data row9 col1" >0.929688</td>
#       <td id="T_7dfed_row9_col2" class="data row9 col2" >0.746082</td>
#       <td id="T_7dfed_row9_col3" class="data row9 col3" >128.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7dfed_level0_row10" class="row_heading level0 row10" >Snow</th>
#       <td id="T_7dfed_row10_col0" class="data row10 col0" >0.472637</td>
#       <td id="T_7dfed_row10_col1" class="data row10 col1" >0.708955</td>
#       <td id="T_7dfed_row10_col2" class="data row10 col2" >0.567164</td>
#       <

# %% [markdown]
# The poor prediction results on labels Frost, Glaze and Snow probably means that the model have a difficult to differentiate them in reason of their similarity. Fogsmog and Sandstorm have a excellent classification score because of remarkable differences of these weathers from others.

# %% [markdown]
# # Validating the model
#
# Randomly selected 2 images for each label and predicted. To better visualization, it plots the image with the legend of its true label and the predicted label.

# %%
sample_labels = unique_labels * 2
sample_labels.sort()

sample_images = np.array([])
np.random.seed(404)
for label in sample_labels:
    sample = df.query("label == '%s'" % label).sample(1)
    sample_images = np.append(sample_images, sample["image"].values)

# %%
plt.figure(figsize=(24, 18))

for j, img in enumerate(sample_images):
    ax = plt.subplot(5, 5, j + 1)
    image = cv2.imread(img)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (256, 256), interpolation=cv2.INTER_AREA)
    
    plt.imshow(image)
    plt.axis("off")
    
    image = np.array(image, dtype=np.float32)
    image_tensor = torch.from_numpy(image).permute(2, 0, 1).unsqueeze(0).to(args["device"])
    index = np.argmax(net(image_tensor).cpu().detach().numpy())
    y_pred = unique_labels[index]
    
    text = "Real: \n%s \n\nPredicted: \n%s" % (sample_labels[j].title(), y_pred.title())
    ax.text(s=text, y=160, x=320, fontsize=16, font=font, ha="center")

plt.suptitle("Predicted x Real Validation Images", font=font, fontsize=28)
plt.show()

# %% [markdown]
# As verified before, the model mistakes Frost with Glaze and Rime because of their similarities. The remainder labels generalized very well.

# %% [markdown]
# #  Conclusion
#
# The model mistakes Frost with Hail and Rime in evaluation, that increases the loss in validation during training.
# The model has an accuracy of 63% in new images.
#
# In this notebook we implemented the training on single RTX3070 GPUs and got a wall time of **1min 19secs** for training of 20 epochs
